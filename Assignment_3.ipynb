# %% [markdown]
# # 1. Why are functions advantageous to have in your programs?

# %% [markdown]
# A function reduces the time to code, small blocks of codes are needn't to be written again and again, just call the function and it does the work for you.

# %% [markdown]
# # 2. When does the code in a function run: when it&#39;s specified or when it&#39;s called?

# %% [markdown]
# The code executes when the function is called.

# %% [markdown]
# # 3. What statement creates a function?

# %% [markdown]
# "def" statemenr defines or creates a function.

# %% [markdown]
# # 4. What is the difference between a function and a function call?

# %% [markdown]
# A function is a block of code while function call is when the function is being called and executed. A function is a def statement while the code is a clause or block

# %% [markdown]
# # 5. How many global scopes are there in a Python program? How many local scopes?

# %% [markdown]
# There is only one global scope, and a local scope is created ehenever a function is called.

# %% [markdown]
# # 6. What happens to variables in a local scope when the function call returns?

# %% [markdown]
# The local scope is destroyed and the variables are forgotten.

# %% [markdown]
# # 7. What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [markdown]
# A return value is the value that a function call evaluates, a return can be a part of an expression.

# %% [markdown]
# # 8. If a function does not have a return statement, what is the return value of a call to that function?

# %% [markdown]
# There would be no return value. or none.

# %% [markdown]
# # 9. How do you make a function variable refer to the global variable?

# %% [markdown]
# A globval statement wwill force a var in a fun to refer to the global var.

# %% [markdown]
# # 10. What is the data type of None?

# %% [markdown]
# NoneType

# %% [markdown]
# # 11. What does the sentence import areallyourpetsnamederic do?

# %% [markdown]
# It imports the module named "areallyourpetsnamederic". (It is not a real python module :D)

# %% [markdown]
# # 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %% [markdown]
# spam.bacon()

# %% [markdown]
# # 13. What can you do to save a programme from crashing if it encounters an error?

# %% [markdown]
# Use a try clause.

# %% [markdown]
# # 14. What is the purpose of the try clause? What is the purpose of the except clause?

# %% [markdown]
# "try" is used for the codes that could cause error, the code executes if an error occurs then comes the next clause "except"
