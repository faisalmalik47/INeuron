# %% [markdown]
# # 1. What is the name of the feature responsible for generating Regex objects?

# %% [markdown]
# re.compile()

# %% [markdown]
# # 2. Why do raw strings often appear in Regex objects?

# %% [markdown]
# So that backslashes dont get ignored.

# %% [markdown]
# # 3. What is the return value of the search() method?

# %% [markdown]
# It returns a Match object.

# %% [markdown]
# # 4. From a Match item, how do you get the actual strings that match the pattern?

# %% [markdown]
# By using group() function, it returns a string of the matched text.

# %% [markdown]
# # 5. In the regex which created from the r&#39;(\d\d\d)-(\d\d\d-\d\d\d\d)&#39;, what does group zero cover? Group 2? Group 1?

# %% [markdown]
# Group 0 = entire match,
#
# group 1 = first set of parentheses,
#
# and group 2 = second set of parentheses.

# %% [markdown]
# # 6. In standard expression syntax, parentheses and intervals have distinct meanings. How can you tell a regex that you want it to fit real parentheses and periods?

# %% [markdown]
# This can be done by using a backslash.

# %% [markdown]
# # 7. The findall() method returns a string list or a list of string tuples. What causes it to return one of the two options?

# %% [markdown]
# regex has no groups = a list of strings is returned.
#
# regex has groups = list of tuples of strings is returned.

# %% [markdown]
# # 8. In standard expressions, what does the | character mean?

# %% [markdown]
# or

# %% [markdown]
# # 9. In regular expressions, what does the character stand for?

# %% [markdown]
# I cant answer this because i dont see any character in the assignment question. Please rectify the Problem.

# %% [markdown]
# # 10.In regular expressions, what is the difference between the + and * characters?

# %% [markdown]
# "+" = matches one or more
#
# "*" = matches zero or more

# %% [markdown]
# # 11. What is the difference between {4} and {4,5} in regular expression?

# %% [markdown]
# {3} matches exactly three instances of the preceding group.
#
# {3,5} matches between three and five instances.

# %% [markdown]
# # 12. What do you mean by the \d, \w, and \s shorthand character classes signify in regular expressions?

# %% [markdown]
# \d = digit,
#
# \w = word,
#
# \s = space

# %% [markdown]
# # 13. What do means by \D, \W, and \S shorthand character classes signify in regular expressions?

# %% [markdown]
# \D = not a digit,
#
# \W = not a word,
#
# \S = not a space

# %% [markdown]
#  # 14. What is the difference between " . * ?" and " . * ?"

# %% [markdown]
# Error in this question, please rectify.

# %% [markdown]
# # 15. What is the syntax for matching both numbers and lowercase letters with a character class?

# %% [markdown]
# [0-9a-z] or [a-z0-9]

# %% [markdown]
# # 16. What is the procedure for making a normal expression in regax case insensitive?

# %% [markdown]
# If we pass re.I or re.IGNORECASE as a second argument to re.compile(),
#
# then it will make the matching cases insensitive.

# %% [markdown]
# # 17. What does the . character normally match? What does it match if re.DOTALL is passed as 2nd argument in re.compile()?

# %% [markdown]
# The . character will matche any character except a newline character.
#
# If re.DOTALL is passed as a second argument to re.compile(), then the dot will also match newline characters.

# %% [markdown]
# # 18. If numReg = re.compile(r&#39;\d+&#39;), what will numRegex.sub(&#39;X&#39;, &#39;11 drummers, 10 pipers, five rings, 4 hen&#39;) return?

# %% [markdown]
# 'X drummers, X pipers, five rings, X hens'

# %% [markdown]
# # 19. What does passing re.VERBOSE as the 2nd argument to re.compile() allow to do?

# %% [markdown]
# it allows us to add whitespace and comments to the string passed to re.compile().

# %% [markdown]
# # 20. How would you write a regex that match a number with comma for every three digits? It must match the given following:
#
# # &#39;42&#39;
# # &#39;1,234&#39;
# # &#39;6,368,745&#39;

# %% [markdown]
# re.compile(r'^\d{1,3}(,\d{3})*$')
